# %%
import os

nome = input("\nQual seu nome? ")
altura = float(input("\nQual a sua altura?"))
peso = int(input("\nQual o seu peso?"))
os.system('clear')
print(nome)
print(altura, 'm')
print(peso, 'kg')
imc = peso / (altura**2)
if imc >= 18.5 and imc <= 24.9:
    print("peso normal")
elif imc >= 25 and imc >= 29.9:
    print("sobrepeso")
elif imc < 18.5:
    print("abaixo do peso")
# Out:
# Qual seu nome? Ale
#
# Qual a sua altura?1.62
#
# Qual o seu peso?54
# Ale
# 1.62 m
# 54 kg
# peso normal

# %%
my_list = list(range(1,7))
my_list = my_list.append(8)
print (my_list)
# Out:
# None

# %%
languages = {}
languages[1,1] = "C++"
languages[2,0] = "PHP"
languages[2] = "Python"

print(languages)
# Out:
# {(1, 1): 'C++', (2, 0): 'PHP', 2: 'Python'}

# %%
x = 5
y = x > 3
print(y)
# Out:
# True
